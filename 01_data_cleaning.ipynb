# %%
import pandas as pd
print(pd.__file__)
print(pd.__version__)
# Out:
# C:\Users\Sobiya Anjum\anaconda3\Lib\site-packages\pandas\__init__.py
# 2.3.3

# %%
df=pd.read_csv("amazon_ecommerce_1M.csv",nrows=10000)

# %%
df.head(10)
# Out:
#    user_id product_id     category subcategory    brand     price  discount  \
# 0  U356787     P39256  Electronics      Mobile      H&M  33090.51     10.46
# 1  U198246     P38657       Sports     Outdoor  Samsung   9368.97      5.32
# 2  U539898     P38893       Sports     Fitness      H&M  14756.85     26.00
# 3  U325772     P54118       Beauty      Makeup     Sony    668.83     24.81
# 4  U865179     P70217         Home       Decor     Sony  10881.29     48.63
# 5  U705397     P35203         Home       Decor       HP   6155.63     17.64
# 6  U498591     P46434         Home   Furniture   Adidas   1104.92     37.81
# 7  U738720     P93227     Clothing        Kids     Sony   1899.42     63.23
# 8  U330283     P99733       Beauty      Makeup     Sony   3611.18     24.77
# 9  U694731     P51245       Beauty      Makeup    Apple   3826.65      8.46
#
#    final_price  rating  review_count  stock seller_id  seller_rating  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             10000 non-null  object
#  1   product_id          10000 non-null  object
#  2   category            10000 non-null  object
#  3   subcategory         10000 non-null  object
#  4   brand               10000 non-null  object
#  5   price               10000 non-null  float64
#  6   discount            10000 non-null  float64
#  7   final_price         10000 non-null  float64
#  8   rating              10000 non-null  float64
#  9   review_count        10000 non-null  int64
#  10  stock               10000 non-null  int64
#  11  seller_id           10000 non-null  object
#  12  seller_rating       10000 non-null  float64
#  13  purchase_date       10000 non-null  object
#  14  shipping_time_days  10000 non-null  int64
# ...

# %%
df.describe()
# Out:
#               price      discount   final_price        rating  review_count  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean   13207.301858     29.095905   9941.594609      3.924850     31.896200
# std    18136.311929     14.697815  14374.517144      0.522677     41.872723
# min      200.140000      5.010000    111.800000      2.000000      0.000000
# 25%     2732.495000     17.057500   1708.965000      3.600000     10.000000
# 50%     4938.020000     28.235000   3759.295000      3.900000     19.000000
# 75%    14062.495000     39.302500  10392.950000      4.300000     38.000000
# max    79885.530000     69.960000  74701.480000      5.000000    783.000000
#
#               stock  seller_rating  shipping_time_days
# count  10000.000000   10000.000000        10000.000000
# mean     249.759900       3.759730            3.203500
# std      143.953134       0.722135            1.676117
# min        0.000000       2.500000            1.000000
# ...

# %%
df.shape
# Out:
# (10000, 20)

# %%
df.columns
# Out:
# Index(['user_id', 'product_id', 'category', 'subcategory', 'brand', 'price',
#        'discount', 'final_price', 'rating', 'review_count', 'stock',
#        'seller_id', 'seller_rating', 'purchase_date', 'shipping_time_days',
#        'location', 'device', 'payment_method', 'is_returned',
#        'delivery_status'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# user_id               0
# product_id            0
# category              0
# subcategory           0
# brand                 0
# price                 0
# discount              0
# final_price           0
# rating                0
# review_count          0
# stock                 0
# seller_id             0
# seller_rating         0
# purchase_date         0
# shipping_time_days    0
# location              0
# device                0
# payment_method        0
# is_returned           0
# delivery_status       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
